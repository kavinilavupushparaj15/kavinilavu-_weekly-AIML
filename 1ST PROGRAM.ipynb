# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\KAVINILAVU P'

# %%
dataframe=pd.read_csv(r"C:\Users\KAVINILAVU P\OneDrive\weekly task\csv")
# give your file path
print(dataframe.head())
